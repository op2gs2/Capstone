# %%
import json
import urllib
import sys
import os
import time
import re
import hashlib

_sha256 = '[a-z0-9]{64}' # sha256에 맞는 정규표현식 정의

path_dir = 'C:/OfficeSetup.exe'
file_list = os.listdir(path_dir)

sha256_pattern = re.compile(_sha256)

class vtAPI():
    def __init__(self):
        self.api = 'dbae55ce231bd44e635b5310d293fa247b2c98c8ee5664b8100a3fb65b035fb6'
        self.base = 'https://www.virustotal.com/vtapi/v2/'
        
    # Virustotal에 주어진 악성코드가 검사된 적이 있는지 확인
    def getReport(self,sha256):
        param = {'resource':sha256,'apikey':self.api,'allinfo': '1'}
        url = self.base + "file/report"
        data = urllib.parse.urlencode(param) # Python 3에는 urllib가 나뉘어져 있음 (parse, request)
        data = data.encode('utf-8') # urlopen()에 data를 넣기 위해, 인코딩이 되어 있어야 함.
        result = urllib.request.urlopen(url,data)

        jdata = json.loads(result.read())
        print(jdata)

        if jdata['response_code'] == 0:
            print(sha256 + " -- Not Found in VT")
            return "no"
        else:
            print("=== Results for SHA256: ", jdata['sha256'], "\tDetected by: ", jdata['positives'])
            return jdata['positives']

    # Virustotal에 악성코드 검사를 의뢰함
    def reqScan(self,filepath):
        print("- Requesting a new scan")
        param = {'file':filepath,'apikey':self.api}
        url = self.base + "file/scan"
        data = urllib.parse.urlencode(param) # Python 3에는 urllib가 나뉘어져 있음 (parse, request)
        data = data.encode('utf-8') # urlopen()에 data를 넣기 위해, 인코딩이 되어 있어야 함.
        result = urllib.request.urlopen(url,data)

        jdata = json.loads(result.read())

        return jdata
    
    # sha256해쉬값을 구함
    def getSha256(self, filepath, blocksize=8192):
        sha256 = hashlib.sha256()
        try:
            f = open(filepath, "rb")
        except IOError as e:
            print("file open error", e)
            return
        while True:
            buf = f.read(blocksize)
            if not buf:
                break
            sha256.update(buf)
        return sha256.hexdigest()


def main():
    vt = vtAPI()
    i = 0
    for file in file_list:
        before = path_dir + "/" + file
        name_check = re.search(sha256_pattern, file) # 악성코드 파일명이 sha256형식에 맞는지 확인

        if name_check == None:
            file = vt.getSha256(before)


        i += 1
        rns = vt.getReport(file) #rns는 악성코드가 백신에 탐지된 갯수를 의미함

        if(rns == "no"): # Virustotal에 악성코드 검사 이력이 없을 때
            file_path = os.getcwd() + "/" + file
            rns = vt.reqScan(file_path)
            file = rns['sha256']

            while True: # 이후 검사이력이 생성될때까지 실행
                time.sleep(20)
                rns = vt.getReport(file)
                if(rns != "no"):
                    break

        after = path_dir + "/" + str(rns) + "#" + file # 본 코드를 처리한 악성코드의 이름 변경

        print("Processed " + str(i) + " files - "+ after)
        os.rename(before, after)

        time.sleep(15)

if __name__ == '__main__':
    main()
# Out:
# {'scans': {'Bkav': {'detected': False, 'version': '1.3.0.9899', 'result': None, 'update': '20210105'}, 'Lionic': {'detected': False, 'version': '4.2', 'result': None, 'update': '20210105'}, 'Elastic': {'detected': True, 'version': '4.0.14', 'result': 'malicious (high confidence)', 'update': '20201214'}, 'DrWeb': {'detected': True, 'version': '7.0.49.9080', 'result': 'Trojan.Solimba.55', 'update': '20210105'}, 'MicroWorld-eScan': {'detected': True, 'version': '14.0.409.0', 'result': 'Trojan.GenericKD.35924501', 'update': '20210105'}, 'FireEye': {'detected': True, 'version': '32.36.1.0', 'result': 'Generic.mg.0dcf5cfe19363ce9', 'update': '20210105'}, 'CAT-QuickHeal': {'detected': True, 'version': '14.00', 'result': 'PUA.Appsinstal.Gen', 'update': '20210105'}, 'ALYac': {'detected': True, 'version': '1.1.3.1', 'result': 'Trojan.GenericKD.35924501', 'update': '20210105'}, 'Cylance': {'detected': True, 'version': '2.3.1.101', 'result': 'Unsafe', 'update': '20210105'}, 'Zillya': {'detected': True, 'version': '2.0.0.4262', 'result': 'Adware.BetterSurfCRT.Win32.419', 'update': '20210102'}, 'Paloalto': {'detected': False, 'version': '1.0', 'result': None, 'update': '20210105'}, 'Sangfor': {'detected': True, 'version': '1.0', 'result': 'Malware', 'update': '20210105'}, 'K7AntiVirus': {'detected': True, 'version': '11.159.36114', 'result': 'Unwanted-Program ( 0049365d1 )', 'update': '20210105'}, 'Alibaba': {'detected': True, 'version': '0.3.0.5', 'result': 'AdWare:Win32/Fiseria.cd49c359', 'update': '20190527'}, 'K7GW': {'detected': True, 'version': '11.159.36115', 'result': 'Adware ( 004f69001 )', 'update': '20210105'}, 'Cybereason': {'detected': False, 'version': '1.2.449', 'result': None, 'update': '20201222'}, 'BitDefenderTheta': {'detected': True, 'version': '7.2.37796.0', 'result': 'Gen:NN.ZemsilF.34742.km0@a0MyuFg', 'update': '20210105'}, 'Cyren': {'detected': False, 'version': '6.3.0.2', 'result': None, 'update': '20210105'}, 'Symantec': {'detected': True, 'version': '1.13.0.0', 'result': 'PUA.Downloader', 'update': '20210105'}, 'ESET-NOD32': {'detected': True, 'version': '22593', 'result': 'MSIL/Solimba potentially unwanted', 'update': '20210105'}, 'APEX': {'detected': True, 'version': '6.117', 'result': 'Malicious', 'update': '20210105'}, 'TotalDefense': {'detected': False, 'version': '37.1.62.1', 'result': None, 'update': '20201217'}, 'Avast': {'detected': True, 'version': '21.1.5827.0', 'result': 'Win32:Solimba-C [PUP]', 'update': '20210105'}, 'ClamAV': {'detected': False, 'version': '0.102.3.0', 'result': None, 'update': '20210105'}, 'Kaspersky': {'detected': True, 'version': '15.0.1.13', 'result': 'not-a-virus:AdWare.Win32.Fiseria.t', 'update': '20210105'}, 'BitDefender': {'detected': True, 'version': '7.2', 'result': 'Trojan.GenericKD.35924501', 'update': '20210105'}, 'NANO-Antivirus': {'detected': True, 'version': '1.0.146.25255', 'result': 'Riskware.Win32.Fiseria.dwzbat', 'update': '20210105'}, 'SUPERAntiSpyware': {'detected': False, 'version': '5.6.0.1032', 'result': None, 'update': '20210101'}, 'Tencent': {'detected': False, 'version': '1.0.0.1', 'result': None, 'update': '20210105'}, 'Ad-Aware': {'detected': True, 'version': '3.0.16.117', 'result': 'Trojan.GenericKD.35924501', 'update': '20210105'}, 'TACHYON': {'detected': False, 'version': '2021-01-05.02', 'result': None, 'update': '20210105'}, 'Emsisoft': {'detected': True, 'version': '2018.12.0.1641', 'result': 'Application.AdWrap (A)', 'update': '20210105'}, 'Comodo': {'detected': True, 'version': '33143', 'result': 'Application.Win32.Solimba.GW@4yj4h5', 'update': '20210105'}, 'F-Secure': {'detected': True, 'version': '12.0.86.52', 'result': 'PotentialRisk.PUA/Solimba.Gen', 'update': '20210105'}, 'Baidu': {'detected': False, 'version': '1.0.0.2', 'result': None, 'update': '20190318'}, 'VIPRE': {'detected': True, 'version': '89444', 'result': 'DownloadMR (fs)', 'update': '20210105'}, 'TrendMicro': {'detected': True, 'version': '11.0.0.1006', 'result': 'TROJ_GEN.R002C ...
# === Results for SHA256:  d4d878b7d9848777119f6ea7ac3907445eaef3d24b0abf83a6c93b14b02818b8 	Detected by:  52
# Processed 1 files - /home/user/Desktop/dataset/malware/52#d4d878b7d9848777119f6ea7ac3907445eaef3d24b0abf83a6c93b14b02818b8
# {'scans': {'Bkav': {'detected': True, 'version': '1.3.0.9899', 'result': 'W32.BarackF.Trojan', 'update': '20211123'}, 'Lionic': {'detected': False, 'version': '4.2', 'result': None, 'update': '20211123'}, 'Elastic': {'detected': True, 'version': '4.0.31', 'result': 'malicious (high confidence)', 'update': '20211118'}, 'MicroWorld-eScan': {'detected': True, 'version': '14.0.409.0', 'result': 'Trojan.Ransomware.GenericKD.32177572', 'update': '20211123'}, 'FireEye': {'detected': True, 'version': '32.44.1.0', 'result': 'Generic.mg.2337089f52251079', 'update': '20211123'}, 'CAT-QuickHeal': {'detected': False, 'version': '14.00', 'result': None, 'update': '20211123'}, 'ALYac': {'detected': True, 'version': '1.1.3.1', 'result': 'Trojan.Ransomware.GenericKD.32177572', 'update': '20211124'}, 'Cylance': {'detected': True, 'version': '2.3.1.101', 'result': 'Unsafe', 'update': '20211124'}, 'VIPRE': {'detected': True, 'version': '97172', 'result': 'Trojan.Win32.Generic!BT', 'update': '20211123'}, 'Sangfor': {'detected': True, 'version': '2.9.0.0', 'result': 'Trojan.Win32.Save.a', 'update': '20211123'}, 'K7AntiVirus': {'detected': True, 'version': '11.229.39458', 'result': 'Trojan ( 00516fdf1 )', 'update': '20211123'}, 'Alibaba': {'detected': True, 'version': '0.3.0.5', 'result': 'Trojan:Win32/Chapak.8a51e947', 'update': '20190527'}, 'K7GW': {'detected': True, 'version': '11.229.39462', 'result': 'Trojan ( 00516fdf1 )', 'update': '20211124'}, 'Cybereason': {'detected': True, 'version': '1.2.449', 'result': 'malicious.f52251', 'update': '20210330'}, 'Baidu': {'detected': False, 'version': '1.0.0.2', 'result': None, 'update': '20190318'}, 'Cyren': {'detected': True, 'version': '6.3.0.2', 'result': 'W32/GandCrab.Y.gen!Eldorado', 'update': '20211124'}, 'Symantec': {'detected': True, 'version': '1.16.0.0', 'result': 'Trojan Horse', 'update': '20211123'}, 'ESET-NOD32': {'detected': True, 'version': '24342', 'result': 'a variant of Win32/Kryptik.GKNP', 'update': '20211124'}, 'APEX': {'detected': True, 'version': '6.232', 'result': 'Malicious', 'update': '20211122'}, 'Paloalto': {'detected': True, 'version': '1.0', 'result': 'generic.ml', 'update': '20211124'}, 'ClamAV': {'detected': False, 'version': '0.104.1.0', 'result': None, 'update': '20211123'}, 'Kaspersky': {'detected': True, 'version': '21.0.1.45', 'result': 'Trojan.Win32.Chapak.asnd', 'update': '20211124'}, 'BitDefender': {'detected': True, 'version': '7.2', 'result': 'Trojan.Ransomware.GenericKD.32177572', 'update': '20211123'}, 'NANO-Antivirus': {'detected': True, 'version': '1.0.146.25409', 'result': 'Trojan.Win32.Chapak.fhnyen', 'update': '20211123'}, 'SUPERAntiSpyware': {'detected': True, 'version': '5.6.0.1032', 'result': 'Trojan.Agent/Gen-Kryptik', 'update': '20211120'}, 'Avast': {'detected': True, 'version': '21.1.5827.0', 'result': 'Win32:Trojan-gen', 'update': '20211124'}, 'Tencent': {'detected': True, 'version': '1.0.0.1', 'result': 'Win32.Trojan.Chapak.Hoep', 'update': '20211124'}, 'Ad-Aware': {'detected': True, 'version': '3.0.21.193', 'result': 'Trojan.Ransomware.GenericKD.32177572', 'update': '20211124'}, 'Emsisoft': {'detected': True, 'version': '2021.5.0.7597', 'result': 'Trojan.Ransomware.GenericKD.32177572 (B)', 'update': '20211123'}, 'Comodo': {'detected': True, 'version': '34044', 'result': 'Malware@#1y5sebvrijso0', 'update': '20211102'}, 'F-Secure': {'detected': False, 'version': '12.0.86.52', 'result': None, 'update': '20211123'}, 'DrWeb': {'detected': True, 'version': '7.0.52.8270', 'result': 'Win32.HLLW.Autoruner2.47136', 'update': '20211124'}, 'Zillya': {'detected': True, 'version': '2.0.0.4503', 'result': 'Trojan.GenericKD.Win32.196701', 'update': '20211123'}, 'TrendMicro': {'detected': True, 'version': '11.0.0.1006', 'result': 'Trojan.Win32.PHORPIEX.AR', 'update': '20211123'}, 'CMC': {'detected': False, 'version': '2.10.2019.1', 'result': None, 'update': '20211026'}, 'Sophos': {'detected': True, 'version': '1.4.1.0', 'result': 'Mal/Generic-R + Mal/GandCrab-B',  ...
# === Results for SHA256:  c522418670b4efa6c754ea19bf18e60d31e8c17929038cd3f14317134230a6e6 	Detected by:  57
# Processed 2 files - /home/user/Desktop/dataset/malware/57#c522418670b4efa6c754ea19bf18e60d31e8c17929038cd3f14317134230a6e6
# {'scans': {'Bkav': {'detected': False, 'version': '1.3.0.9899', 'result': None, 'update': '20210116'}, 'Lionic': {'detected': False, 'version': '4.2', 'result': None, 'update': '20210118'}, 'Elastic': {'detected': False, 'version': '4.0.15', 'result': None, 'update': '20210107'}, 'MicroWorld-eScan': {'detected': False, 'version': '14.0.409.0', 'result': None, 'update': '20210118'}, 'FireEye': {'detected': False, 'version': '32.36.1.0', 'result': None, 'update': '20210118'}, 'CAT-QuickHeal': {'detected': False, 'version': '14.00', 'result': None, 'update': '20210118'}, 'McAfee': {'detected': False, 'version': '6.0.6.653', 'result': None, 'update': '20210118'}, 'Cylance': {'detected': False, 'version': '2.3.1.101', 'result': None, 'update': '20210118'}, 'Zillya': {'detected': False, 'version': '2.0.0.4272', 'result': None, 'update': '20210116'}, 'Paloalto': {'detected': False, 'version': '1.0', 'result': None, 'update': '20210118'}, 'K7AntiVirus': {'detected': True, 'version': '11.160.36232', 'result': 'Riskware ( 0040eff71 )', 'update': '20210118'}, 'Alibaba': {'detected': False, 'version': '0.3.0.5', 'result': None, 'update': '20190527'}, 'K7GW': {'detected': True, 'version': '11.160.36232', 'result': 'Riskware ( 0040eff71 )', 'update': '20210118'}, 'Cybereason': {'detected': True, 'version': '1.2.449', 'result': 'malicious.6e9272', 'update': '20210106'}, 'Baidu': {'detected': False, 'version': '1.0.0.2', 'result': None, 'update': '20190318'}, 'Cyren': {'detected': False, 'version': '6.3.0.2', 'result': None, 'update': '20210118'}, 'Symantec': {'detected': False, 'version': '1.13.0.0', 'result': None, 'update': '20210117'}, 'TotalDefense': {'detected': False, 'version': '37.1.62.1', 'result': None, 'update': '20201217'}, 'APEX': {'detected': True, 'version': '6.121', 'result': 'Malicious', 'update': '20210116'}, 'Avast': {'detected': False, 'version': '21.1.5827.0', 'result': None, 'update': '20210118'}, 'ClamAV': {'detected': False, 'version': '0.102.3.0', 'result': None, 'update': '20210117'}, 'Kaspersky': {'detected': False, 'version': '15.0.1.13', 'result': None, 'update': '20210118'}, 'BitDefender': {'detected': False, 'version': '7.2', 'result': None, 'update': '20210118'}, 'NANO-Antivirus': {'detected': False, 'version': '1.0.146.25255', 'result': None, 'update': '20210118'}, 'SUPERAntiSpyware': {'detected': False, 'version': '5.6.0.1032', 'result': None, 'update': '20210115'}, 'Tencent': {'detected': False, 'version': '1.0.0.1', 'result': None, 'update': '20210118'}, 'Ad-Aware': {'detected': False, 'version': '3.0.16.117', 'result': None, 'update': '20210118'}, 'Sophos': {'detected': False, 'version': '1.0.2.0', 'result': None, 'update': '20210117'}, 'Comodo': {'detected': False, 'version': '33181', 'result': None, 'update': '20210117'}, 'F-Secure': {'detected': False, 'version': '12.0.86.52', 'result': None, 'update': '20210118'}, 'DrWeb': {'detected': False, 'version': '7.0.49.9080', 'result': None, 'update': '20210118'}, 'VIPRE': {'detected': False, 'version': '89752', 'result': None, 'update': '20210118'}, 'McAfee-GW-Edition': {'detected': False, 'version': 'v2019.1.2+3728', 'result': None, 'update': '20210117'}, 'CMC': {'detected': False, 'version': '2.10.2019.1', 'result': None, 'update': '20210116'}, 'Emsisoft': {'detected': False, 'version': '2018.12.0.1641', 'result': None, 'update': '20210118'}, 'Ikarus': {'detected': False, 'version': '0.1.5.2', 'result': None, 'update': '20210117'}, 'GData': {'detected': False, 'version': 'A:25.28383B:27.21633', 'result': None, 'update': '20210118'}, 'Jiangmin': {'detected': False, 'version': '16.0.100', 'result': None, 'update': '20210118'}, 'MaxSecure': {'detected': False, 'version': '1.0.0.1', 'result': None, 'update': '20201212'}, 'Avira': {'detected': False, 'version': '8.3.3.10', 'result': None, 'update': '20210118'}, 'MAX': {'detected': False, 'version': '2019.9.16.1', 'result': None, 'update': '20210118'}, 'Antiy-AVL': {'detected': False, 'version': '3.0.0.1', 'resu ...
# === Results for SHA256:  4980f93d3680570d9df211c2efb65ff2eabb809b6e25dd6845d634444c5e2be0 	Detected by:  6
# Processed 3 files - /home/user/Desktop/dataset/malware/6#4980f93d3680570d9df211c2efb65ff2eabb809b6e25dd6845d634444c5e2be0
# {'scans': {'Bkav': {'detected': False, 'version': '1.3.0.9899', 'result': None, 'update': '20210105'}, 'Lionic': {'detected': False, 'version': '4.2', 'result': None, 'update': '20210105'}, 'Elastic': {'detected': True, 'version': '4.0.14', 'result': 'malicious (high confidence)', 'update': '20201214'}, 'DrWeb': {'detected': True, 'version': '7.0.49.9080', 'result': 'Trojan.Click2.64259', 'update': '20210105'}, 'MicroWorld-eScan': {'detected': True, 'version': '14.0.409.0', 'result': 'Adware.Linkury.CY', 'update': '20210105'}, 'FireEye': {'detected': True, 'version': '32.36.1.0', 'result': 'Generic.mg.0cc3d221b4f653d0', 'update': '20210105'}, 'CAT-QuickHeal': {'detected': True, 'version': '14.00', 'result': 'PUA.Linkularll.Gen', 'update': '20210105'}, 'ALYac': {'detected': True, 'version': '1.1.3.1', 'result': 'Adware.Linkury.CY', 'update': '20210105'}, 'Cylance': {'detected': True, 'version': '2.3.1.101', 'result': 'Unsafe', 'update': '20210105'}, 'Zillya': {'detected': True, 'version': '2.0.0.4262', 'result': 'Adware.LinkunGen.Win32.1', 'update': '20210102'}, 'Paloalto': {'detected': False, 'version': '1.0', 'result': None, 'update': '20210105'}, 'Sangfor': {'detected': False, 'version': '1.0', 'result': None, 'update': '20210105'}, 'K7AntiVirus': {'detected': True, 'version': '11.159.36114', 'result': 'Riskware ( 00527b3d1 )', 'update': '20210105'}, 'Alibaba': {'detected': False, 'version': '0.3.0.5', 'result': None, 'update': '20190527'}, 'K7GW': {'detected': True, 'version': '11.159.36112', 'result': 'Riskware ( 00527b3d1 )', 'update': '20210105'}, 'Cybereason': {'detected': True, 'version': '1.2.449', 'result': 'malicious.1b4f65', 'update': '20201222'}, 'BitDefenderTheta': {'detected': False, 'version': '7.2.37796.0', 'result': None, 'update': '20210105'}, 'Cyren': {'detected': False, 'version': '6.3.0.2', 'result': None, 'update': '20210105'}, 'Symantec': {'detected': True, 'version': '1.13.0.0', 'result': 'PUA.Gen.3', 'update': '20210105'}, 'ESET-NOD32': {'detected': True, 'version': '22593', 'result': 'multiple detections', 'update': '20210105'}, 'APEX': {'detected': True, 'version': '6.117', 'result': 'Malicious', 'update': '20210105'}, 'TotalDefense': {'detected': True, 'version': '37.1.62.1', 'result': 'Win32/Tnega.ATXM', 'update': '20201217'}, 'Avast': {'detected': True, 'version': '21.1.5827.0', 'result': 'NSIS:Linkular-A [Adw]', 'update': '20210105'}, 'ClamAV': {'detected': False, 'version': '0.102.3.0', 'result': None, 'update': '20210105'}, 'Kaspersky': {'detected': True, 'version': '15.0.1.13', 'result': 'not-a-virus:AdWare.Win32.Linkun.a', 'update': '20210105'}, 'BitDefender': {'detected': True, 'version': '7.2', 'result': 'Adware.Linkury.CY', 'update': '20210105'}, 'NANO-Antivirus': {'detected': True, 'version': '1.0.146.25255', 'result': 'Riskware.Win32.Crypter.ficngn', 'update': '20210105'}, 'SUPERAntiSpyware': {'detected': True, 'version': '5.6.0.1032', 'result': 'Trojan.Agent/Gen-DarkKomet', 'update': '20210101'}, 'Rising': {'detected': True, 'version': '25.0.0.26', 'result': 'Adware.Linkury/NSIS!1.BF78 (CLASSIC:ifhD/VOgfQuYW9myZzfshQ)', 'update': '20210105'}, 'Ad-Aware': {'detected': False, 'version': '3.0.16.117', 'result': None, 'update': '20210105'}, 'TACHYON': {'detected': True, 'version': '2021-01-05.02', 'result': 'Trojan-Clicker/W32.Linkun.456240.B', 'update': '20210105'}, 'Sophos': {'detected': True, 'version': '1.0.2.0', 'result': 'Linkular (PUA)', 'update': '20210105'}, 'Comodo': {'detected': True, 'version': '33143', 'result': 'Application.Win32.Linkular.A@4xpg3z', 'update': '20210105'}, 'F-Secure': {'detected': True, 'version': '12.0.86.52', 'result': 'Adware.ADWARE/Adware.Gen', 'update': '20210105'}, 'Baidu': {'detected': True, 'version': '1.0.0.2', 'result': 'NSIS.Adware.Linkular.a', 'update': '20190318'}, 'VIPRE': {'detected': True, 'version': '89444', 'result': 'Trojan.Win32.Generic!BT', 'update': '20210105'}, 'TrendMicro': {'detected': False, 'version': '11.0.0.1006', 'result': None, ' ...
# === Results for SHA256:  e1f0b17c7d3432e47ce95d5e8d78989b7b8ec3664b59ce9eaba30b2adeac0897 	Detected by:  50
# Processed 4 files - /home/user/Desktop/dataset/malware/50#e1f0b17c7d3432e47ce95d5e8d78989b7b8ec3664b59ce9eaba30b2adeac0897
# {'scans': {'Bkav': {'detected': False, 'version': '1.3.0.9899', 'result': None, 'update': '20210105'}, 'Lionic': {'detected': True, 'version': '4.2', 'result': 'Trojan.Win32.Blocker.j!c', 'update': '20210105'}, 'Elastic': {'detected': True, 'version': '4.0.14', 'result': 'malicious (high confidence)', 'update': '20201214'}, 'MicroWorld-eScan': {'detected': True, 'version': '14.0.409.0', 'result': 'Gen:Variant.Razy.628274', 'update': '20210105'}, 'FireEye': {'detected': True, 'version': '32.36.1.0', 'result': 'Generic.mg.0bcc615d4cc4ba9c', 'update': '20210105'}, 'CAT-QuickHeal': {'detected': False, 'version': '14.00', 'result': None, 'update': '20210105'}, 'ALYac': {'detected': True, 'version': '1.1.3.1', 'result': 'Gen:Variant.Razy.628274', 'update': '20210105'}, 'Cylance': {'detected': True, 'version': '2.3.1.101', 'result': 'Unsafe', 'update': '20210105'}, 'VIPRE': {'detected': True, 'version': '89444', 'result': 'Trojan.Win32.Generic!BT', 'update': '20210105'}, 'Paloalto': {'detected': True, 'version': '1.0', 'result': 'generic.ml', 'update': '20210105'}, 'Sangfor': {'detected': True, 'version': '1.0', 'result': 'Malware', 'update': '20210105'}, 'K7AntiVirus': {'detected': True, 'version': '11.159.36112', 'result': 'Trojan-Downloader ( 005705951 )', 'update': '20210105'}, 'Alibaba': {'detected': True, 'version': '0.3.0.5', 'result': 'Trojan:Win32/Starter.ali2000005', 'update': '20190527'}, 'K7GW': {'detected': True, 'version': '11.159.36112', 'result': 'Trojan-Downloader ( 005705951 )', 'update': '20210105'}, 'Cybereason': {'detected': True, 'version': '1.2.449', 'result': 'malicious.d4cc4b', 'update': '20201222'}, 'BitDefenderTheta': {'detected': True, 'version': '7.2.37796.0', 'result': 'AI:Packer.402135741F', 'update': '20210105'}, 'Cyren': {'detected': False, 'version': '6.3.0.2', 'result': None, 'update': '20210105'}, 'Symantec': {'detected': True, 'version': '1.13.0.0', 'result': 'ML.Attribute.HighConfidence', 'update': '20210105'}, 'TotalDefense': {'detected': False, 'version': '37.1.62.1', 'result': None, 'update': '20201217'}, 'Baidu': {'detected': False, 'version': '1.0.0.2', 'result': None, 'update': '20190318'}, 'APEX': {'detected': True, 'version': '6.117', 'result': 'Malicious', 'update': '20210105'}, 'Avast': {'detected': True, 'version': '21.1.5827.0', 'result': 'Win32:Malware-gen', 'update': '20210105'}, 'ClamAV': {'detected': False, 'version': '0.102.3.0', 'result': None, 'update': '20210105'}, 'Kaspersky': {'detected': True, 'version': '15.0.1.13', 'result': 'Trojan-Ransom.Win32.Blocker.btnl', 'update': '20210105'}, 'BitDefender': {'detected': True, 'version': '7.2', 'result': 'Gen:Variant.Razy.628274', 'update': '20210105'}, 'NANO-Antivirus': {'detected': True, 'version': '1.0.146.25255', 'result': 'Trojan.Win32.Comet.ecrymi', 'update': '20210105'}, 'SUPERAntiSpyware': {'detected': False, 'version': '5.6.0.1032', 'result': None, 'update': '20210101'}, 'Tencent': {'detected': True, 'version': '1.0.0.1', 'result': 'Win32.Trojan.Blocker.Isy', 'update': '20210105'}, 'Ad-Aware': {'detected': True, 'version': '3.0.16.117', 'result': 'Gen:Variant.Razy.628274', 'update': '20210105'}, 'Sophos': {'detected': True, 'version': '1.0.2.0', 'result': 'Mal/Generic-S', 'update': '20210105'}, 'Comodo': {'detected': True, 'version': '33143', 'result': 'Malware@#vvvsu6hrpmsv', 'update': '20210105'}, 'F-Secure': {'detected': True, 'version': '12.0.86.52', 'result': 'Heuristic.HEUR/AGEN.1127014', 'update': '20210105'}, 'DrWeb': {'detected': True, 'version': '7.0.49.9080', 'result': 'BackDoor.Comet.152', 'update': '20210105'}, 'Zillya': {'detected': True, 'version': '2.0.0.4262', 'result': 'Dropper.Agent.Win32.256955', 'update': '20210102'}, 'TrendMicro': {'detected': False, 'version': '11.0.0.1006', 'result': None, 'update': '20210105'}, 'McAfee-GW-Edition': {'detected': True, 'version': 'v2019.1.2+3728', 'result': 'BehavesLike.Win32.Generic.dc', 'update': '20210105'}, 'CMC': {'detected': False, 'version': '2.10.2019.1', 'res ...
# === Results for SHA256:  bb666bc8e9a1efebf3cd4e37cc9b8f5ee096d1ccf356f3699e893d932c68e77a 	Detected by:  54
# Processed 5 files - /home/user/Desktop/dataset/malware/54#bb666bc8e9a1efebf3cd4e37cc9b8f5ee096d1ccf356f3699e893d932c68e77a
# {'scans': {'Bkav': {'detected': False, 'version': '1.3.0.10239', 'result': None, 'update': '20190820'}, 'Lionic': {'detected': True, 'version': '4.2', 'result': 'Trojan.Win32.Autoit.4!c', 'update': '20190821'}, 'TotalDefense': {'detected': True, 'version': '37.1.62.1', 'result': 'Win32/Inject.NCcWETD', 'update': '20190821'}, 'MicroWorld-eScan': {'detected': True, 'version': '14.0.297.0', 'result': 'Gen:Trojan.Heur.AutoIT.13', 'update': '20190821'}, 'FireEye': {'detected': True, 'version': '29.7.0.0', 'result': 'Generic.mg.e2d80fd725b6959d', 'update': '20190821'}, 'CAT-QuickHeal': {'detected': False, 'version': '14.00', 'result': None, 'update': '20190820'}, 'McAfee': {'detected': True, 'version': '6.0.6.653', 'result': 'Artemis!E2D80FD725B6', 'update': '20190821'}, 'Cylance': {'detected': True, 'version': '2.3.1.101', 'result': 'Unsafe', 'update': '20190821'}, 'Paloalto': {'detected': True, 'version': '1.0', 'result': 'generic.ml', 'update': '20190821'}, 'K7AntiVirus': {'detected': True, 'version': '11.62.31795', 'result': 'Trojan ( 004b408b1 )', 'update': '20190821'}, 'Alibaba': {'detected': True, 'version': '0.3.0.5', 'result': 'Trojan:Win32/Autoit.2b89cb7c', 'update': '20190527'}, 'K7GW': {'detected': True, 'version': '11.62.31795', 'result': 'Trojan ( 004b408b1 )', 'update': '20190821'}, 'Cybereason': {'detected': True, 'version': '1.2.449', 'result': 'malicious.725b69', 'update': '20190616'}, 'Baidu': {'detected': False, 'version': '1.0.0.2', 'result': None, 'update': '20190318'}, 'F-Prot': {'detected': False, 'version': '4.7.1.166', 'result': None, 'update': '20190821'}, 'Symantec': {'detected': True, 'version': '1.10.0.0', 'result': 'ML.Attribute.HighConfidence', 'update': '20190821'}, 'ESET-NOD32': {'detected': True, 'version': '19889', 'result': 'a variant of Win32/Injector.Autoit.BFF', 'update': '20190821'}, 'APEX': {'detected': True, 'version': '5.53', 'result': 'Malicious', 'update': '20190819'}, 'Avast': {'detected': True, 'version': '18.4.3895.0', 'result': 'Win32:Malware-gen', 'update': '20190821'}, 'ClamAV': {'detected': True, 'version': '0.101.3.0', 'result': 'Win.Malware.Autoit-7056659-0', 'update': '20190820'}, 'Kaspersky': {'detected': True, 'version': '15.0.1.13', 'result': 'Trojan.Win32.Autoit.esr', 'update': '20190821'}, 'BitDefender': {'detected': True, 'version': '7.2', 'result': 'Gen:Trojan.Heur.AutoIT.13', 'update': '20190821'}, 'NANO-Antivirus': {'detected': True, 'version': '1.0.134.24859', 'result': 'Trojan.Win32.Autoit.eanuzv', 'update': '20190821'}, 'SUPERAntiSpyware': {'detected': False, 'version': '5.6.0.1032', 'result': None, 'update': '20190816'}, 'Tencent': {'detected': False, 'version': '1.0.0.1', 'result': None, 'update': '20190821'}, 'Endgame': {'detected': True, 'version': '3.0.14', 'result': 'malicious (high confidence)', 'update': '20190819'}, 'Emsisoft': {'detected': True, 'version': '2018.12.0.1641', 'result': 'Gen:Trojan.Heur.AutoIT.13 (B)', 'update': '20190821'}, 'Comodo': {'detected': True, 'version': '31353', 'result': 'Malware@#cvt53wibeype', 'update': '20190821'}, 'F-Secure': {'detected': True, 'version': '12.0.86.52', 'result': 'Dropper.DR/AutoIt.Gen8', 'update': '20190821'}, 'DrWeb': {'detected': True, 'version': '7.0.41.7240', 'result': 'Trojan.Packed.29505', 'update': '20190821'}, 'Zillya': {'detected': True, 'version': '2.0.0.3882', 'result': 'Worm.AutoItGen.Win32.445', 'update': '20190820'}, 'Invincea': {'detected': True, 'version': '6.3.6.26157', 'result': 'heuristic', 'update': '20190717'}, 'McAfee-GW-Edition': {'detected': True, 'version': 'v2017.3010', 'result': 'BehavesLike.Win32.Agent.th', 'update': '20190820'}, 'Fortinet': {'detected': True, 'version': '5.4.247.0', 'result': 'W32/Autoit.BFF!tr', 'update': '20190821'}, 'Trapmine': {'detected': True, 'version': '3.1.62.789', 'result': 'malicious.moderate.ml.score', 'update': '20190522'}, 'CMC': {'detected': False, 'version': '1.1.0.977', 'result': None, 'update': '20190321'}, 'Sophos': {'detected': True, 'version':  ...
# === Results for SHA256:  436f95d81ff4749d18b57f58ed02b7c1afcdc91de77f0a418be090bbf8506471 	Detected by:  50
# Processed 6 files - /home/user/Desktop/dataset/malware/50#436f95d81ff4749d18b57f58ed02b7c1afcdc91de77f0a418be090bbf8506471
# {'scans': {'Bkav': {'detected': False, 'version': '1.3.0.9899', 'result': None, 'update': '20210105'}, 'Lionic': {'detected': False, 'version': '4.2', 'result': None, 'update': '20210105'}, 'Elastic': {'detected': True, 'version': '4.0.14', 'result': 'malicious (high confidence)', 'update': '20201214'}, 'MicroWorld-eScan': {'detected': True, 'version': '14.0.409.0', 'result': 'Adware.Linkury.CY', 'update': '20210105'}, 'FireEye': {'detected': True, 'version': '32.36.1.0', 'result': 'Generic.mg.0dbafd434d06ec9a', 'update': '20210105'}, 'CAT-QuickHeal': {'detected': True, 'version': '14.00', 'result': 'PUA.Linkularll.Gen', 'update': '20210105'}, 'ALYac': {'detected': True, 'version': '1.1.3.1', 'result': 'Adware.Linkury.CY', 'update': '20210105'}, 'Cylance': {'detected': True, 'version': '2.3.1.101', 'result': 'Unsafe', 'update': '20210105'}, 'Zillya': {'detected': True, 'version': '2.0.0.4262', 'result': 'Adware.LinkunGen.Win32.1', 'update': '20210102'}, 'Paloalto': {'detected': False, 'version': '1.0', 'result': None, 'update': '20210105'}, 'Sangfor': {'detected': False, 'version': '1.0', 'result': None, 'update': '20210105'}, 'K7AntiVirus': {'detected': True, 'version': '11.159.36114', 'result': 'Riskware ( 00527b3d1 )', 'update': '20210105'}, 'Alibaba': {'detected': False, 'version': '0.3.0.5', 'result': None, 'update': '20190527'}, 'K7GW': {'detected': True, 'version': '11.159.36115', 'result': 'Riskware ( 00527b3d1 )', 'update': '20210105'}, 'CrowdStrike': {'detected': True, 'version': '1.0', 'result': 'win/malicious_confidence_100% (D)', 'update': '20190702'}, 'BitDefenderTheta': {'detected': False, 'version': '7.2.37796.0', 'result': None, 'update': '20210105'}, 'Cyren': {'detected': False, 'version': '6.3.0.2', 'result': None, 'update': '20210105'}, 'Symantec': {'detected': True, 'version': '1.13.0.0', 'result': 'PUA.Gen.3', 'update': '20210105'}, 'TotalDefense': {'detected': True, 'version': '37.1.62.1', 'result': 'Win32/Tnega.ATXM', 'update': '20201217'}, 'Baidu': {'detected': True, 'version': '1.0.0.2', 'result': 'NSIS.Adware.Linkular.a', 'update': '20190318'}, 'TrendMicro-HouseCall': {'detected': False, 'version': '10.0.0.1040', 'result': None, 'update': '20210105'}, 'Avast': {'detected': True, 'version': '21.1.5827.0', 'result': 'NSIS:Linkular-A [Adw]', 'update': '20210105'}, 'ClamAV': {'detected': False, 'version': '0.102.3.0', 'result': None, 'update': '20210105'}, 'Kaspersky': {'detected': True, 'version': '15.0.1.13', 'result': 'not-a-virus:AdWare.Win32.Linkun.a', 'update': '20210105'}, 'BitDefender': {'detected': True, 'version': '7.2', 'result': 'Adware.Linkury.CY', 'update': '20210105'}, 'NANO-Antivirus': {'detected': True, 'version': '1.0.146.25255', 'result': 'Riskware.Win32.Crypter.ficngn', 'update': '20210105'}, 'SUPERAntiSpyware': {'detected': True, 'version': '5.6.0.1032', 'result': 'Trojan.Agent/Gen-DarkKomet', 'update': '20210101'}, 'Rising': {'detected': True, 'version': '25.0.0.26', 'result': 'Adware.Linkury/NSIS!1.BF78 (CLASSIC:ifhD/VOgfQuYW9myZzfshQ)', 'update': '20210105'}, 'Ad-Aware': {'detected': False, 'version': '3.0.16.117', 'result': None, 'update': '20210105'}, 'TACHYON': {'detected': True, 'version': '2021-01-05.02', 'result': 'Trojan-Clicker/W32.Linkun.456240.B', 'update': '20210105'}, 'Sophos': {'detected': True, 'version': '1.0.2.0', 'result': 'Linkular (PUA)', 'update': '20210105'}, 'Comodo': {'detected': True, 'version': '33143', 'result': 'Application.Win32.Linkular.A@4xpg3z', 'update': '20210105'}, 'F-Secure': {'detected': True, 'version': '12.0.86.52', 'result': 'Adware.ADWARE/Adware.Gen', 'update': '20210105'}, 'DrWeb': {'detected': True, 'version': '7.0.49.9080', 'result': 'Trojan.Click2.64259', 'update': '20210105'}, 'VIPRE': {'detected': True, 'version': '89444', 'result': 'Trojan.Win32.Generic!BT', 'update': '20210105'}, 'TrendMicro': {'detected': False, 'version': '11.0.0.1006', 'result': None, 'update': '20210105'}, 'McAfee-GW-Edition': {'detected': True, 'version': 'v2019 ...
# === Results for SHA256:  d3fa4d49ac6c5d4dea674b9e5d8532a0c3f563379e987b3953e831244af89ef3 	Detected by:  50
# Processed 7 files - /home/user/Desktop/dataset/malware/50#d3fa4d49ac6c5d4dea674b9e5d8532a0c3f563379e987b3953e831244af89ef3
# {'scans': {'TotalDefense': {'detected': False, 'version': '37.1.62.1', 'result': None, 'update': '20201217'}, 'MicroWorld-eScan': {'detected': False, 'version': '14.0.409.0', 'result': None, 'update': '20210105'}, 'FireEye': {'detected': True, 'version': '32.36.1.0', 'result': 'Generic.mg.0a2dcb52edb4da86', 'update': '20210105'}, 'CAT-QuickHeal': {'detected': True, 'version': '14.00', 'result': 'PUA.Ironinstal.Gen', 'update': '20210105'}, 'McAfee': {'detected': True, 'version': '6.0.6.653', 'result': 'Artemis!0A2DCB52EDB4', 'update': '20210105'}, 'Cylance': {'detected': True, 'version': '2.3.1.101', 'result': 'Unsafe', 'update': '20210105'}, 'Zillya': {'detected': True, 'version': '2.0.0.4262', 'result': 'Trojan.InstallCoreCRTD.Win32.1657', 'update': '20210102'}, 'Sangfor': {'detected': True, 'version': '1.0', 'result': 'Malware', 'update': '20210105'}, 'K7AntiVirus': {'detected': True, 'version': '11.159.36114', 'result': 'Unwanted-Program ( 004a9cdd1 )', 'update': '20210105'}, 'Alibaba': {'detected': True, 'version': '0.3.0.5', 'result': 'Downloader:Win32/InstallCore.22e913a1', 'update': '20190527'}, 'K7GW': {'detected': True, 'version': '11.159.36115', 'result': 'Unwanted-Program ( 004a9cdd1 )', 'update': '20210105'}, 'CrowdStrike': {'detected': True, 'version': '1.0', 'result': 'win/malicious_confidence_100% (D)', 'update': '20190702'}, 'Cyren': {'detected': True, 'version': '6.3.0.2', 'result': 'W32/InstallCore.R3.gen!Eldorado', 'update': '20210105'}, 'Symantec': {'detected': True, 'version': '1.13.0.0', 'result': 'PUA.InstallCore', 'update': '20210105'}, 'ESET-NOD32': {'detected': False, 'version': '22595', 'result': None, 'update': '20210105'}, 'APEX': {'detected': True, 'version': '6.117', 'result': 'Malicious', 'update': '20210105'}, 'Paloalto': {'detected': False, 'version': '1.0', 'result': None, 'update': '20210105'}, 'ClamAV': {'detected': True, 'version': '0.102.3.0', 'result': 'Win.Malware.Installcore-6866209-0', 'update': '20210105'}, 'Kaspersky': {'detected': True, 'version': '15.0.1.13', 'result': 'not-a-virus:HEUR:AdWare.Win32.InstallCore.gen', 'update': '20210105'}, 'BitDefender': {'detected': False, 'version': '7.2', 'result': None, 'update': '20210105'}, 'NANO-Antivirus': {'detected': True, 'version': '1.0.146.25255', 'result': 'Riskware.Win32.InstallCore.dcuoai', 'update': '20210105'}, 'SUPERAntiSpyware': {'detected': True, 'version': '5.6.0.1032', 'result': 'PUP.InstallCore/Variant', 'update': '20210101'}, 'Avast': {'detected': True, 'version': '21.1.5827.0', 'result': 'Win32:Installer-I [PUP]', 'update': '20210105'}, 'Tencent': {'detected': True, 'version': '1.0.0.1', 'result': 'Malware.Win32.Gencirc.10bab3f6', 'update': '20210105'}, 'Ad-Aware': {'detected': False, 'version': '3.0.16.117', 'result': None, 'update': '20210105'}, 'Emsisoft': {'detected': True, 'version': '2018.12.0.1641', 'result': 'Application.InstallCore (A)', 'update': '20210105'}, 'Comodo': {'detected': True, 'version': '33144', 'result': 'ApplicUnwnt.Win32.InstallCore.D@4zcy73', 'update': '20210105'}, 'F-Secure': {'detected': True, 'version': '12.0.86.52', 'result': 'PotentialRisk.PUA/InstallCore.Gen7', 'update': '20210105'}, 'DrWeb': {'detected': True, 'version': '7.0.49.9080', 'result': 'Adware.InstallCore.122', 'update': '20210105'}, 'VIPRE': {'detected': True, 'version': '89450', 'result': 'InstallCore (fs)', 'update': '20210105'}, 'TrendMicro': {'detected': False, 'version': '11.0.0.1006', 'result': None, 'update': '20210105'}, 'CMC': {'detected': False, 'version': '2.10.2019.1', 'result': None, 'update': '20201224'}, 'Sophos': {'detected': True, 'version': '1.0.2.0', 'result': 'Install Core Click run software (PUA)', 'update': '20210105'}, 'Ikarus': {'detected': True, 'version': '0.1.5.2', 'result': 'PUA.InstallCore', 'update': '20210105'}, 'Jiangmin': {'detected': False, 'version': '16.0.100', 'result': None, 'update': '20210105'}, 'Webroot': {'detected': True, 'version': '1.0.0.403', 'result': 'Pua.Iron.Install', 'update': ' ...
# === Results for SHA256:  c1b77004d9f4d8487b7741b98fad46339e8466d2dba506ccf51d1dbf5a51b4d9 	Detected by:  41
# Processed 8 files - /home/user/Desktop/dataset/malware/41#c1b77004d9f4d8487b7741b98fad46339e8466d2dba506ccf51d1dbf5a51b4d9
# {'scans': {'Bkav': {'detected': False, 'version': '1.3.0.9899', 'result': None, 'update': '20210105'}, 'Lionic': {'detected': True, 'version': '4.2', 'result': 'Adware.NSIS.Generic.2!c', 'update': '20210105'}, 'Elastic': {'detected': True, 'version': '4.0.14', 'result': 'malicious (high confidence)', 'update': '20201214'}, 'DrWeb': {'detected': False, 'version': '7.0.49.9080', 'result': None, 'update': '20210105'}, 'MicroWorld-eScan': {'detected': False, 'version': '14.0.409.0', 'result': None, 'update': '20210105'}, 'FireEye': {'detected': True, 'version': '32.36.1.0', 'result': 'Generic.mg.0c9750c8b1fefbd7', 'update': '20210105'}, 'CAT-QuickHeal': {'detected': False, 'version': '14.00', 'result': None, 'update': '20210105'}, 'ALYac': {'detected': False, 'version': '1.1.3.1', 'result': None, 'update': '20210105'}, 'Cylance': {'detected': True, 'version': '2.3.1.101', 'result': 'Unsafe', 'update': '20210105'}, 'VIPRE': {'detected': True, 'version': '89444', 'result': 'Adware.NSIS.Baserch', 'update': '20210105'}, 'Sangfor': {'detected': True, 'version': '1.0', 'result': 'Malware', 'update': '20210105'}, 'K7AntiVirus': {'detected': False, 'version': '11.159.36114', 'result': None, 'update': '20210105'}, 'BitDefender': {'detected': False, 'version': '7.2', 'result': None, 'update': '20210105'}, 'K7GW': {'detected': False, 'version': '11.159.36112', 'result': None, 'update': '20210105'}, 'Cybereason': {'detected': False, 'version': '1.2.449', 'result': None, 'update': '20201222'}, 'Arcabit': {'detected': False, 'version': '1.0.0.881', 'result': None, 'update': '20210105'}, 'BitDefenderTheta': {'detected': False, 'version': '7.2.37796.0', 'result': None, 'update': '20210105'}, 'Cyren': {'detected': False, 'version': '6.3.0.2', 'result': None, 'update': '20210105'}, 'Symantec': {'detected': True, 'version': '1.13.0.0', 'result': 'SecurityRisk.gen1', 'update': '20210105'}, 'TotalDefense': {'detected': False, 'version': '37.1.62.1', 'result': None, 'update': '20201217'}, 'APEX': {'detected': True, 'version': '6.117', 'result': 'Malicious', 'update': '20210105'}, 'Avast': {'detected': True, 'version': '21.1.5827.0', 'result': 'Win32:Malware-gen', 'update': '20210105'}, 'ClamAV': {'detected': False, 'version': '0.102.3.0', 'result': None, 'update': '20210105'}, 'Kaspersky': {'detected': True, 'version': '15.0.1.13', 'result': 'not-a-virus:AdWare.NSIS.Baserch.gen', 'update': '20210105'}, 'Alibaba': {'detected': True, 'version': '0.3.0.5', 'result': 'AdWare:Win32/Baserch.576c2dad', 'update': '20190527'}, 'NANO-Antivirus': {'detected': True, 'version': '1.0.146.25255', 'result': 'Trojan.Win32.AutoRun.bkwqbp', 'update': '20210105'}, 'ViRobot': {'detected': False, 'version': '2014.3.20.0', 'result': None, 'update': '20210105'}, 'Tencent': {'detected': True, 'version': '1.0.0.1', 'result': 'Win32.Worm.Autorun.Hzb', 'update': '20210105'}, 'Ad-Aware': {'detected': False, 'version': '3.0.16.117', 'result': None, 'update': '20210105'}, 'TACHYON': {'detected': False, 'version': '2021-01-05.02', 'result': None, 'update': '20210105'}, 'Sophos': {'detected': True, 'version': '1.0.2.0', 'result': 'Generic PUA PK (PUA)', 'update': '20210105'}, 'Comodo': {'detected': True, 'version': '33143', 'result': 'Malware@#adhqxebfohca', 'update': '20210105'}, 'F-Secure': {'detected': False, 'version': '12.0.86.52', 'result': None, 'update': '20210105'}, 'Baidu': {'detected': False, 'version': '1.0.0.2', 'result': None, 'update': '20190318'}, 'Zillya': {'detected': False, 'version': '2.0.0.4262', 'result': None, 'update': '20210102'}, 'TrendMicro': {'detected': False, 'version': '11.0.0.1006', 'result': None, 'update': '20210105'}, 'McAfee-GW-Edition': {'detected': True, 'version': 'v2019.1.2+3728', 'result': 'Artemis!PUP', 'update': '20210105'}, 'CMC': {'detected': False, 'version': '2.10.2019.1', 'result': None, 'update': '20201224'}, 'Emsisoft': {'detected': False, 'version': '2018.12.0.1641', 'result': None, 'update': '20210105'}, 'SentinelOne': {'detected': T ...
# === Results for SHA256:  42b9d4ba22f7d5fb2c0200ab6100980bc747031d8ce2c9b3d536232a23117237 	Detected by:  34
# Processed 9 files - /home/user/Desktop/dataset/malware/34#42b9d4ba22f7d5fb2c0200ab6100980bc747031d8ce2c9b3d536232a23117237
# {'scans': {'Bkav': {'detected': True, 'version': '1.3.0.9899', 'result': 'W32.AIDetectVM.malware2', 'update': '20210105'}, 'Lionic': {'detected': False, 'version': '4.2', 'result': None, 'update': '20210105'}, 'Elastic': {'detected': True, 'version': '4.0.14', 'result': 'malicious (high confidence)', 'update': '20201214'}, 'MicroWorld-eScan': {'detected': True, 'version': '14.0.409.0', 'result': 'Gen:Trojan.ProcessHijack.arX@aOl6hwei', 'update': '20210105'}, 'FireEye': {'detected': True, 'version': '32.36.1.0', 'result': 'Generic.mg.0e534a1ced9c46bd', 'update': '20210105'}, 'CAT-QuickHeal': {'detected': True, 'version': '14.00', 'result': 'PUA.iBryte.DC4', 'update': '20210105'}, 'McAfee': {'detected': True, 'version': '6.0.6.653', 'result': 'Artemis!0E534A1CED9C', 'update': '20210105'}, 'Cylance': {'detected': True, 'version': '2.3.1.101', 'result': 'Unsafe', 'update': '20210105'}, 'Zillya': {'detected': True, 'version': '2.0.0.4262', 'result': 'Adware.iBryteCRT.Win32.435', 'update': '20210102'}, 'Paloalto': {'detected': True, 'version': '1.0', 'result': 'generic.ml', 'update': '20210105'}, 'Sangfor': {'detected': True, 'version': '1.0', 'result': 'Malware', 'update': '20210105'}, 'K7AntiVirus': {'detected': True, 'version': '11.159.36114', 'result': 'Trojan ( 004a943d1 )', 'update': '20210105'}, 'Alibaba': {'detected': True, 'version': '0.3.0.5', 'result': 'AdWare:Win32/iBryte.db0e0582', 'update': '20190527'}, 'K7GW': {'detected': True, 'version': '11.159.36115', 'result': 'Trojan ( 004a943d1 )', 'update': '20210105'}, 'Cybereason': {'detected': True, 'version': '1.2.449', 'result': 'malicious.ced9c4', 'update': '20201222'}, 'BitDefenderTheta': {'detected': False, 'version': '7.2.37796.0', 'result': None, 'update': '20210105'}, 'Cyren': {'detected': True, 'version': '6.3.0.2', 'result': 'W32/Ibryte.D.gen!Eldorado', 'update': '20210105'}, 'Symantec': {'detected': True, 'version': '1.13.0.0', 'result': 'SMG.Heur!gen', 'update': '20210105'}, 'TotalDefense': {'detected': False, 'version': '37.1.62.1', 'result': None, 'update': '20201217'}, 'Baidu': {'detected': True, 'version': '1.0.0.2', 'result': 'Win32.Trojan.Delf.in', 'update': '20190318'}, 'TrendMicro-HouseCall': {'detected': False, 'version': '10.0.0.1040', 'result': None, 'update': '20210105'}, 'Avast': {'detected': True, 'version': '21.1.5827.0', 'result': 'Win32:IBryte-BR [PUP]', 'update': '20210105'}, 'ClamAV': {'detected': True, 'version': '0.102.3.0', 'result': 'Win.Adware.Agent-1222143', 'update': '20210105'}, 'Kaspersky': {'detected': True, 'version': '15.0.1.13', 'result': 'not-a-virus:AdWare.Win32.iBryte.jcs', 'update': '20210105'}, 'BitDefender': {'detected': True, 'version': '7.2', 'result': 'Gen:Trojan.ProcessHijack.arX@aOl6hwei', 'update': '20210105'}, 'NANO-Antivirus': {'detected': True, 'version': '1.0.146.25255', 'result': 'Trojan.Win32.Ibryte.fonkal', 'update': '20210105'}, 'SUPERAntiSpyware': {'detected': True, 'version': '5.6.0.1032', 'result': 'PUP.OptimumInstaller/Variant', 'update': '20210101'}, 'Tencent': {'detected': True, 'version': '1.0.0.1', 'result': 'Malware.Win32.Gencirc.10b3ae07', 'update': '20210105'}, 'Ad-Aware': {'detected': True, 'version': '3.0.16.117', 'result': 'Gen:Trojan.ProcessHijack.arX@aOl6hwei', 'update': '20210105'}, 'TACHYON': {'detected': True, 'version': '2021-01-05.02', 'result': 'Trojan-Clicker/W32.iBryte.1059480', 'update': '20210105'}, 'Emsisoft': {'detected': True, 'version': '2018.12.0.1641', 'result': 'Application.Downloader (A)', 'update': '20210105'}, 'Comodo': {'detected': True, 'version': '33143', 'result': 'Application.Win32.iBryte.M@4zv25t', 'update': '20210105'}, 'F-Secure': {'detected': True, 'version': '12.0.86.52', 'result': 'Adware.ADWARE/iBryte.afc', 'update': '20210105'}, 'DrWeb': {'detected': True, 'version': '7.0.49.9080', 'result': 'Trojan.iBryte.539', 'update': '20210105'}, 'VIPRE': {'detected': True, 'version': '89444', 'result': 'Trojan.Win32.Generic!BT', 'update': '20210105'}, 'TrendMicro': {'detect ...
# === Results for SHA256:  b1e6ee5ad65f98a20ec0166ba0f876b6bfcb65aa69202c68d49990f2e07f0eec 	Detected by:  61
# Processed 10 files - /home/user/Desktop/dataset/malware/61#b1e6ee5ad65f98a20ec0166ba0f876b6bfcb65aa69202c68d49990f2e07f0eec
# {'scans': {'Bkav': {'detected': True, 'version': '1.3.0.9899', 'result': 'W32.AIDetect.malware1', 'update': '20220330'}, 'Lionic': {'detected': True, 'version': '7.5', 'result': 'Trojan.Win32.Khalesi.4!c', 'update': '20220330'}, 'tehtris': {'detected': False, 'version': 'v0.0.7', 'result': None, 'update': '20220330'}, 'Cynet': {'detected': True, 'version': '4.0.0.27', 'result': 'Malicious (score: 100)', 'update': '20220330'}, 'CMC': {'detected': False, 'version': '2.10.2019.1', 'result': None, 'update': '20211026'}, 'CAT-QuickHeal': {'detected': True, 'version': '14.00', 'result': 'Trojan.KhalesiVMF.S21183761', 'update': '20220330'}, 'McAfee': {'detected': True, 'version': '6.0.6.653', 'result': 'Fareit-FMP!11CF5CA49A6C', 'update': '20220330'}, 'Malwarebytes': {'detected': True, 'version': '4.2.2.27', 'result': 'Trojan.MalPack.VB', 'update': '20220330'}, 'Sangfor': {'detected': True, 'version': '2.9.0.0', 'result': 'Trojan.Win32.Occamy.C', 'update': '20211224'}, 'K7AntiVirus': {'detected': True, 'version': '12.3.41562', 'result': 'Trojan ( 0053b76d1 )', 'update': '20220330'}, 'BitDefender': {'detected': True, 'version': '7.2', 'result': 'Gen:Heur.PonyStealer.Wm0@eiPsjvoO', 'update': '20220330'}, 'K7GW': {'detected': True, 'version': '12.3.41561', 'result': 'Trojan ( 0053b76d1 )', 'update': '20220330'}, 'Cybereason': {'detected': True, 'version': '1.2.449', 'result': 'malicious.49a6c3', 'update': '20210330'}, 'Baidu': {'detected': False, 'version': '1.0.0.2', 'result': None, 'update': '20190318'}, 'VirIT': {'detected': True, 'version': '9.5.165', 'result': 'Trojan.Win32.Inject3.PFD', 'update': '20220330'}, 'Cyren': {'detected': True, 'version': '6.5.1.2', 'result': 'W32/Backdoor.DIOV-2542', 'update': '20220330'}, 'Symantec': {'detected': True, 'version': '1.17.0.0', 'result': 'ML.Attribute.HighConfidence', 'update': '20220330'}, 'Elastic': {'detected': True, 'version': '4.0.35', 'result': 'malicious (high confidence)', 'update': '20220302'}, 'ESET-NOD32': {'detected': True, 'version': '25024', 'result': 'a variant of Win32/Injector.EKZT', 'update': '20220330'}, 'APEX': {'detected': True, 'version': '6.275', 'result': 'Malicious', 'update': '20220328'}, 'Paloalto': {'detected': True, 'version': '0.9.0.1003', 'result': 'generic.ml', 'update': '20220330'}, 'ClamAV': {'detected': True, 'version': '0.104.2.0', 'result': 'Win.Ransomware.Hermes-6877144-0', 'update': '20220330'}, 'Kaspersky': {'detected': True, 'version': '21.0.1.45', 'result': 'Trojan.Win32.Khalesi.ijb', 'update': '20220330'}, 'Alibaba': {'detected': True, 'version': '0.3.0.5', 'result': 'Trojan:Win32/Khalesi.97bc7f36', 'update': '20190527'}, 'NANO-Antivirus': {'detected': True, 'version': '1.0.146.25576', 'result': 'Trojan.Win32.Khalesi.fhzfhw', 'update': '20220330'}, 'ViRobot': {'detected': True, 'version': '2014.3.20.0', 'result': 'Trojan.Win32.Z.Symmi.786432.J', 'update': '20220330'}, 'MicroWorld-eScan': {'detected': True, 'version': '14.0.409.0', 'result': 'Gen:Heur.PonyStealer.Wm0@eiPsjvoO', 'update': '20220330'}, 'Avast': {'detected': True, 'version': '21.1.5827.0', 'result': 'FileRepMalware [Misc]', 'update': '20220330'}, 'Tencent': {'detected': True, 'version': '1.0.0.1', 'result': 'Malware.Win32.Gencirc.10cf9adf', 'update': '20220330'}, 'Ad-Aware': {'detected': True, 'version': '3.0.21.193', 'result': 'Gen:Heur.PonyStealer.Wm0@eiPsjvoO', 'update': '20220330'}, 'Sophos': {'detected': True, 'version': '1.4.1.0', 'result': 'ML/PE-A + Troj/Zbot-MHW', 'update': '20220330'}, 'Comodo': {'detected': True, 'version': '34485', 'result': 'Malware@#1jhg69zdyka55', 'update': '20220330'}, 'F-Secure': {'detected': True, 'version': '12.0.86.52', 'result': 'Heuristic.HEUR/AGEN.1239131', 'update': '20220330'}, 'DrWeb': {'detected': True, 'version': '7.0.54.3080', 'result': 'Trojan.Inject3.10273', 'update': '20220330'}, 'Zillya': {'detected': True, 'version': '2.0.0.4601', 'result': 'Trojan.Khalesi.Win32.2071', 'update': '20220330'}, 'TrendMicro': {'detected': True, 'version': ...
# === Results for SHA256:  4e87a0794bf73d06ac1ce4a37e33eb832ff4c89fb9e4266490c7cef9229d27a7 	Detected by:  61
# Processed 11 files - /home/user/Desktop/dataset/malware/61#4e87a0794bf73d06ac1ce4a37e33eb832ff4c89fb9e4266490c7cef9229d27a7
# ...
# === Results for SHA256:  80b4479da4a0f627557bf99480c862552b19ad2ac568180be2ad5275d2cd816d 	Detected by:  42
# Processed 265 files - /home/user/Desktop/dataset/malware/42#80b4479da4a0f627557bf99480c862552b19ad2ac568180be2ad5275d2cd816d
# {'scans': {'Bkav': {'detected': False, 'version': '1.3.0.9899', 'result': None, 'update': '20210105'}, 'Lionic': {'detected': False, 'version': '4.2', 'result': None, 'update': '20210107'}, 'Elastic': {'detected': True, 'version': '4.0.14', 'result': 'malicious (high confidence)', 'update': '20201214'}, 'MicroWorld-eScan': {'detected': False, 'version': '14.0.409.0', 'result': None, 'update': '20210105'}, 'FireEye': {'detected': True, 'version': '32.36.1.0', 'result': 'Generic.mg.0b1056caf259f471', 'update': '20210105'}, 'CAT-QuickHeal': {'detected': True, 'version': '14.00', 'result': 'PUA.Wedownload1.Gen', 'update': '20210105'}, 'Qihoo-360': {'detected': True, 'version': '1.0.0.1120', 'result': 'Win32/Virus.Downloader.a96', 'update': '20210105'}, 'ALYac': {'detected': False, 'version': '1.1.3.1', 'result': None, 'update': '20210105'}, 'Cylance': {'detected': True, 'version': '2.3.1.101', 'result': 'Unsafe', 'update': '20210105'}, 'VIPRE': {'detected': True, 'version': '89444', 'result': 'Soft32Downloader (fs)', 'update': '20210105'}, 'Sangfor': {'detected': True, 'version': '1.0', 'result': 'Malware', 'update': '20210105'}, 'K7AntiVirus': {'detected': True, 'version': '11.159.36114', 'result': 'Adware ( 004d55831 )', 'update': '20210105'}, 'BitDefender': {'detected': False, 'version': '7.2', 'result': None, 'update': '20210105'}, 'K7GW': {'detected': True, 'version': '11.159.36115', 'result': 'Adware ( 004d55831 )', 'update': '20210105'}, 'Cybereason': {'detected': False, 'version': '1.2.449', 'result': None, 'update': '20201222'}, 'Arcabit': {'detected': False, 'version': '1.0.0.881', 'result': None, 'update': '20210105'}, 'BitDefenderTheta': {'detected': True, 'version': '7.2.37796.0', 'result': 'Gen:NN.ZelphiF.34742.8mMfa81euGoi', 'update': '20210105'}, 'Cyren': {'detected': True, 'version': '6.3.0.2', 'result': 'W32/Soft32Download.A.gen!Eldorado', 'update': '20210105'}, 'Symantec': {'detected': True, 'version': '1.13.0.0', 'result': 'SMG.Heur!gen', 'update': '20210105'}, 'ESET-NOD32': {'detected': True, 'version': '22595', 'result': 'a variant of Win32/Soft32Downloader.C potentially unwanted', 'update': '20210105'}, 'Baidu': {'detected': False, 'version': '1.0.0.2', 'result': None, 'update': '20190318'}, 'APEX': {'detected': False, 'version': '6.117', 'result': None, 'update': '20210105'}, 'Avast': {'detected': True, 'version': '21.1.5827.0', 'result': 'Win32:Downloader-TOV [PUP]', 'update': '20210105'}, 'ClamAV': {'detected': True, 'version': '0.102.3.0', 'result': 'Win.Worm.449874-1', 'update': '20210105'}, 'Kaspersky': {'detected': True, 'version': '15.0.1.13', 'result': 'not-a-virus:Downloader.Win32.Soft32.adez', 'update': '20210105'}, 'Alibaba': {'detected': True, 'version': '0.3.0.5', 'result': 'Downloader:Win32/SuspectCRC.cce4e724', 'update': '20190527'}, 'NANO-Antivirus': {'detected': True, 'version': '1.0.146.25255', 'result': 'Trojan.Win32.Soft32Downloader.dwzawx', 'update': '20210105'}, 'ViRobot': {'detected': False, 'version': '2014.3.20.0', 'result': None, 'update': '20210105'}, 'Rising': {'detected': True, 'version': '25.0.0.26', 'result': 'PUF.Soft32Downloader!1.9C52 (CLASSIC)', 'update': '20210105'}, 'Ad-Aware': {'detected': False, 'version': '3.0.16.117', 'result': None, 'update': '20210105'}, 'TACHYON': {'detected': False, 'version': '2021-01-05.02', 'result': None, 'update': '20210105'}, 'Emsisoft': {'detected': True, 'version': '2018.12.0.1641', 'result': 'Application.Downloader (A)', 'update': '20210105'}, 'Comodo': {'detected': True, 'version': '33143', 'result': 'Application.Win32.Agent.S@51hhun', 'update': '20210105'}, 'F-Secure': {'detected': True, 'version': '12.0.86.52', 'result': 'Program.APPL/Soft32Down.diq', 'update': '20210105'}, 'DrWeb': {'detected': True, 'version': '7.0.49.9080', 'result': 'Adware.Downware.10564', 'update': '20210105'}, 'Zillya': {'detected': True, 'version': '2.0.0.4262', 'result': 'Adware.AgentCRT.Win32.28', 'update': '20210102'}, 'TrendMicro': {'detected': False, 'ver ...
# === Results for SHA256:  a1c4b9caa5e2b0b25b5b9e9479876c1f6b86daf4ae8de7d3b53c88a25d96a450 	Detected by:  48
# Processed 266 files - /home/user/Desktop/dataset/malware/48#a1c4b9caa5e2b0b25b5b9e9479876c1f6b86daf4ae8de7d3b53c88a25d96a450
# {'scans': {'Bkav': {'detected': True, 'version': '1.3.0.9899', 'result': 'W32.FamVT.InstallQTTc.Worm', 'update': '20210318'}, 'Lionic': {'detected': True, 'version': '4.2', 'result': 'Trojan.Multi.Generic.muwi', 'update': '20210318'}, 'Elastic': {'detected': True, 'version': '4.0.17', 'result': 'malicious (high confidence)', 'update': '20210217'}, 'MicroWorld-eScan': {'detected': True, 'version': '14.0.409.0', 'result': 'Gen:Application.Bundler.InstallIQ.1', 'update': '20210318'}, 'FireEye': {'detected': True, 'version': '32.44.1.0', 'result': 'Generic.mg.e6e63552ba14e5f7', 'update': '20210318'}, 'CAT-QuickHeal': {'detected': True, 'version': '14.00', 'result': 'PUA.Secureinst1.Gen', 'update': '20210318'}, 'McAfee': {'detected': True, 'version': '6.0.6.653', 'result': 'GenericRXAK-JZ!E6E63552BA14', 'update': '20210318'}, 'Cylance': {'detected': True, 'version': '2.3.1.101', 'result': 'Unsafe', 'update': '20210319'}, 'Zillya': {'detected': True, 'version': '2.0.0.4318', 'result': 'Adware.AgentCRT.Win32.65', 'update': '20210318'}, 'Paloalto': {'detected': True, 'version': '1.0', 'result': 'generic.ml', 'update': '20210319'}, 'Sangfor': {'detected': True, 'version': '2.9.0.0', 'result': 'Suspicious.Win32.Save.a', 'update': '20210318'}, 'K7AntiVirus': {'detected': True, 'version': '11.171.36730', 'result': 'Riskware ( 0040eff71 )', 'update': '20210318'}, 'Alibaba': {'detected': True, 'version': '0.3.0.5', 'result': 'AdWare:Win32/InstallIQ.d6d3599c', 'update': '20190527'}, 'K7GW': {'detected': True, 'version': '11.171.36730', 'result': 'Riskware ( 0040eff71 )', 'update': '20210318'}, 'Cybereason': {'detected': True, 'version': '1.2.449', 'result': 'malicious.2ba14e', 'update': '20210307'}, 'Baidu': {'detected': False, 'version': '1.0.0.2', 'result': None, 'update': '20190318'}, 'Cyren': {'detected': True, 'version': '6.3.0.2', 'result': 'W32/SafeInstall.A.gen!Eldorado', 'update': '20210319'}, 'TotalDefense': {'detected': True, 'version': '37.1.62.1', 'result': 'Win32/Tnega.BJIRJG', 'update': '20210318'}, 'APEX': {'detected': True, 'version': '6.143', 'result': 'Malicious', 'update': '20210316'}, 'Avast': {'detected': True, 'version': '21.1.5827.0', 'result': 'FileRepMetagen [PUP]', 'update': '20210319'}, 'ClamAV': {'detected': True, 'version': '0.103.1.0', 'result': 'Win.Adware.W3i-6606556-1', 'update': '20210318'}, 'Kaspersky': {'detected': True, 'version': '15.0.1.13', 'result': 'not-a-virus:AdWare.Win32.Agent.hjru', 'update': '20210318'}, 'BitDefender': {'detected': True, 'version': '7.2', 'result': 'Gen:Application.Bundler.InstallIQ.1', 'update': '20210319'}, 'NANO-Antivirus': {'detected': True, 'version': '1.0.146.25265', 'result': 'Trojan.Win32.Domaiq.dwtdyk', 'update': '20210318'}, 'SUPERAntiSpyware': {'detected': True, 'version': '5.6.0.1032', 'result': 'PUP.SafeInstall/Variant', 'update': '20210312'}, 'Tencent': {'detected': True, 'version': '1.0.0.1', 'result': 'Malware.Win32.Gencirc.10b20d30', 'update': '20210319'}, 'Ad-Aware': {'detected': True, 'version': '3.0.16.117', 'result': 'Gen:Application.Bundler.InstallIQ.1', 'update': '20210318'}, 'TACHYON': {'detected': False, 'version': '2021-03-18.02', 'result': None, 'update': '20210318'}, 'Emsisoft': {'detected': True, 'version': '2018.12.0.1641', 'result': 'Gen:Application.Bundler.InstallIQ.1 (B)', 'update': '20210318'}, 'Comodo': {'detected': True, 'version': '33357', 'result': 'Application.Win32.InstallIQ.C@5iwskw', 'update': '20210319'}, 'F-Secure': {'detected': False, 'version': '12.0.86.52', 'result': None, 'update': '20210318'}, 'DrWeb': {'detected': True, 'version': '7.0.49.9080', 'result': 'Trojan.DownLoader12.5732', 'update': '20210319'}, 'VIPRE': {'detected': True, 'version': '91188', 'result': 'Trojan.Win32.Generic!BT', 'update': '20210318'}, 'TrendMicro': {'detected': True, 'version': '11.0.0.1006', 'result': 'TROJ_GEN.R002C0OBO21', 'update': '20210318'}, 'McAfee-GW-Edition': {'detected': True, 'version': 'v2019.1.2+3728', 'result': 'BehavesLike.Win32.Obfusca ...
# === Results for SHA256:  3bd039ed71f961e9f2f4979ec2beeb57c9cc39c0ff339c98e04bb897a3ad511b 	Detected by:  58
# Processed 267 files - /home/user/Desktop/dataset/malware/58#3bd039ed71f961e9f2f4979ec2beeb57c9cc39c0ff339c98e04bb897a3ad511b
# {'scans': {'Bkav': {'detected': False, 'version': '1.3.0.10239', 'result': None, 'update': '20190925'}, 'Lionic': {'detected': False, 'version': '4.2', 'result': None, 'update': '20190926'}, 'MicroWorld-eScan': {'detected': True, 'version': '14.0.297.0', 'result': 'Gen:Variant.Ulise.53186', 'update': '20190926'}, 'CMC': {'detected': False, 'version': '1.1.0.977', 'result': None, 'update': '20190321'}, 'CAT-QuickHeal': {'detected': True, 'version': '14.00', 'result': 'PUA.Optimumins.Gen', 'update': '20190925'}, 'McAfee': {'detected': True, 'version': '6.0.6.653', 'result': 'Adware-FOO', 'update': '20190926'}, 'Cylance': {'detected': True, 'version': '2.3.1.101', 'result': 'Unsafe', 'update': '20190926'}, 'Zillya': {'detected': True, 'version': '2.0.0.3909', 'result': 'Adware.AgentCRT.Win32.988', 'update': '20190925'}, 'K7AntiVirus': {'detected': True, 'version': '11.68.32097', 'result': 'Adware ( 005524301 )', 'update': '20190926'}, 'Alibaba': {'detected': True, 'version': '0.3.0.5', 'result': 'AdWare:Win32/Agent.a1c382ae', 'update': '20190527'}, 'K7GW': {'detected': True, 'version': '11.68.32098', 'result': 'Adware ( 005524301 )', 'update': '20190926'}, 'Cybereason': {'detected': True, 'version': '1.2.449', 'result': 'malicious.c850ff', 'update': '20190616'}, 'Arcabit': {'detected': True, 'version': '1.0.0.857', 'result': 'Trojan.Ulise.DCFC2', 'update': '20190925'}, 'TrendMicro': {'detected': False, 'version': '11.0.0.1006', 'result': None, 'update': '20190926'}, 'Baidu': {'detected': True, 'version': '1.0.0.2', 'result': 'Win32.Adware.Generic.ai', 'update': '20190318'}, 'Cyren': {'detected': True, 'version': '6.2.2.2', 'result': 'W32/S-9f9bb110!Eldorado', 'update': '20190926'}, 'Symantec': {'detected': True, 'version': '1.10.0.0', 'result': 'SMG.Heur!gen', 'update': '20190926'}, 'TotalDefense': {'detected': True, 'version': '37.1.62.1', 'result': 'Win32/Zbot.HIE', 'update': '20190925'}, 'APEX': {'detected': True, 'version': '5.66', 'result': 'Malicious', 'update': '20190924'}, 'Paloalto': {'detected': False, 'version': '1.0', 'result': None, 'update': '20190926'}, 'ClamAV': {'detected': True, 'version': '0.101.4.0', 'result': 'Win.Adware.Downware-482', 'update': '20190925'}, 'Kaspersky': {'detected': True, 'version': '15.0.1.13', 'result': 'not-a-virus:AdWare.Win32.Agent.aece', 'update': '20190926'}, 'BitDefender': {'detected': True, 'version': '7.2', 'result': 'Gen:Variant.Ulise.53186', 'update': '20190926'}, 'NANO-Antivirus': {'detected': True, 'version': '1.0.134.24859', 'result': 'Riskware.Win32.IBryte.fohudo', 'update': '20190926'}, 'ViRobot': {'detected': False, 'version': '2014.3.20.0', 'result': None, 'update': '20190926'}, 'Rising': {'detected': True, 'version': '25.0.0.24', 'result': 'Trojan.Win32.Rouge.d (CLASSIC)', 'update': '20190926'}, 'Endgame': {'detected': True, 'version': '3.0.15', 'result': 'malicious (high confidence)', 'update': '20190918'}, 'Sophos': {'detected': True, 'version': '4.98.0', 'result': 'iBryte Optimum Installer (PUA)', 'update': '20190926'}, 'Comodo': {'detected': True, 'version': '31530', 'result': 'Application.Win32.IBryte.ZD@59txd6', 'update': '20190926'}, 'F-Secure': {'detected': True, 'version': '12.0.86.52', 'result': 'Adware.ADWARE/Agent.909545', 'update': '20190926'}, 'DrWeb': {'detected': True, 'version': '7.0.41.7240', 'result': 'Adware.Downware.1285', 'update': '20190926'}, 'VIPRE': {'detected': True, 'version': '78138', 'result': 'Trojan.Win32.Generic!BT', 'update': '20190926'}, 'Invincea': {'detected': True, 'version': '6.3.6.26157', 'result': 'heuristic', 'update': '20190904'}, 'McAfee-GW-Edition': {'detected': True, 'version': 'v2017.3010', 'result': 'BehavesLike.Win32.Adware.ch', 'update': '20190926'}, 'Trapmine': {'detected': False, 'version': '3.1.81.800', 'result': None, 'update': '20190826'}, 'FireEye': {'detected': True, 'version': '29.7.0.0', 'result': 'Generic.mg.0eb40bbc850ff3ec', 'update': '20190926'}, 'Emsisoft': {'detected': True, 'version': '2018.12.0.1641', 'res ...
# === Results for SHA256:  0bcf650854cfc606d04c9ed2cf4609fe2a2d3acb28257260b152a99e5d527205 	Detected by:  55
# Processed 268 files - /home/user/Desktop/dataset/malware/55#0bcf650854cfc606d04c9ed2cf4609fe2a2d3acb28257260b152a99e5d527205
# file open error [Errno 21] Is a directory: '/home/user/Desktop/dataset/malware/.fr-IOx6je'
# {'response_code': 0, 'resource': 'None', 'verbose_msg': 'Invalid resource, check what you are submitting'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [2], in <module>
#      98         time.sleep(15)
#     103 if __name__ == '__main__':
# --> 104     main()
#
# Input In [2], in main()
#      76     file = vt.getSha256(before)
#      79 i += 1
# ---> 80 rns = vt.getReport(file) #rns는 악성코드가 백신에 탐지된 갯수를 의미함
#      82 if(rns == "no"): # Virustotal에 악성코드 검사 이력이 없을 때
#      83     file_path = os.getcwd() + "/" + file
#
# Input In [2], in vtAPI.getReport(self, sha256)
#      30 print(jdata)
#      32 if jdata['response_code'] == 0:
# ---> 33     print(sha256 + " -- Not Found in VT")
#      34     return "no"
#      35 else:
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'
